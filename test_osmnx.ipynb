# %%
import networkx as nx
import osmnx as ox

# %matplotlib inline
ox.config(log_console=True)
ox.__version__
# Out:
# '1.1.0'

# %%
# download/model a street network for some city then visualize it
G = ox.graph_from_place("City of Edinburgh", network_type="drive")
fig, ax = ox.plot_graph(G)

# %%
import osmnx as ox
G = ox.graph_from_address('City of Edinburgh')
ox.plot_graph(G)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
import networkx as nx
import osmnx as ox
from IPython.display import IFrame

# %matplotlib inline
ox.__version__
# Out:
# '0.11.4'

# %%
# download the street network for Piedmont, CA
G = ox.graph_from_place("Piedmont, California, USA", network_type="drive")
# Out:
# /Users/nataliergravett/opt/anaconda3/lib/python3.8/site-packages/osmnx/projection.py:72: FutureWarning: Assigning CRS to a GeoDataFrame without a geometry column is now deprecated and will not be supported in the future.
#   gdf.crs = crs

# %%
# plot the street network with folium
m1 = ox.plot_graph_folium(G, popup_attribute="name")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-66603d8ddf6b> in <module>
#       1 # plot the street network with folium
# ----> 2 m1 = ox.plot_graph_folium(G, popup_attribute="name", color="#8b0000")
#
# TypeError: plot_graph_folium() got an unexpected keyword argument 'color'
