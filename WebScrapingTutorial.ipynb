# %% [markdown]
# # Web Scraping with Python
# All websites are different and each needs a customised approach when it comes to scraping, but we can generally identify 3 main scenarios:
# 1. Website has a publicly available and well documented API. The dream. (rarely comes true)
# 2. Website has all the juicy data present in the source code. Go to your website of choice, right-click anywhere on the page and select View Page Source. If you can find your data of interest somewhere within that HTML code then you're in luck.
# 3. You can see data on the website but when you view source code, it's not there. Huh?? That most likely means that the data is being dynamically loaded via Javascript. We'll have to try and reverse-engineer the website's non-public API.
#
# In this tutorial we'll cover scenarios 2 & 3.
#
# Requirements:
# - Python >= 3.6
# - Chrome browser (if you're using something else you'll have to figure out the names of equivalent tools)

# %% [markdown]
# ## Scenario 2: extracting data from website's HTML code.
# ### First, let's import some libraries

# %%
import pandas as pd  # we'll use pandas to display our scraped data in a table and export to csv / excel etc.
import requests  # requests library allows us to request data from a url using RESTful GET and POST methods
from bs4 import BeautifulSoup  # beautiful soup is a HTML parser
from urllib import parse  # we'll use this to make sure our search terms are url-friendly

# %% [markdown]
# I want to bake some muffins! In fact I love muffins so much, I want to save all recipes from the BBC Good Food website 🧁
#
# I went to https://www.bbc.co.uk/food and searched for `muffins`, then copied the url from my browser.

# %%
url = "https://www.bbc.co.uk/food/search?q=muffins&page=1"
headers = {"user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36"}

# %% [markdown]
# What's this `headers` thing? Well, some websites don't like to be accessed by scripts (BBC is actually pretty lenient in that regard). In case you come across a website that will deny you access, you may be able to get it to work by pretending to be a browser and passing a `headers` parameter in your request. To get the value of the "user-agent", right click anywhere on the page and select "Inspect". In the inspect pane on the right, go to Network tab. Now click anywhere on the page - you should see some network activity. Click on any item in the list - a panel should open on the right with the first tab being "Headers". Scroll down to "Request Headers" - your user-agent info should be there.
#
# Now we want to send a GET request to that url and hopefully get some data back

# %%
# I'm passing my two veriables as arguments into the requests.get() method
r = requests.get(url=url, headers=headers)
print(f"Status code: {r.status_code}")
print(f"Content data type: {type(r.content)}")
# Out:
# Status code: 200
# Content data type: <class 'bytes'>

# %% [markdown]
# HTTP status code indicate whether the response has been successful or not. You can check what each code means on this [Wiki page](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes).
# - 1xx informational response – the request was received, continuing process
# - 2xx successful – the request was successfully received, understood, and accepted
# - 3xx redirection – further action needs to be taken in order to complete the request
# - 4xx client error – the request contains bad syntax or cannot be fulfilled
# - 5xx server error – the server failed to fulfil an apparently valid request
#
# So far so good, we got OK response! But the content of our response is stored as bytes - we'll need to decode it into a string before we can continue.
# The default encoding is "utf-8" but you might come across a website using a different type of encoding (try Russian websites in cyrillic!). Learn more about [Character Encoding](https://en.wikipedia.org/wiki/Character_encoding).

# %%
# let's decode our content
html = r.content.decode(encoding='utf-8')
# and now we can make a soup from it! BS makes sense of all the HTML tags in our content so that we can fish them out of the soup XD
soup = BeautifulSoup(html, "html.parser")

# %% [markdown]
# This is where right-click + Inspect (RCI) becomes your best friend. Right now our soup contains a _a lot_ of stuff we don't need: navigation bars, ads, featured content, footer etc. We need to find the smallest element (HTML tag) that encompasses all of our recipes to narrow down our search area. RCI on the first recipe on the page and keep moving up the HTML tag tree until you find the first tag that holds all recipes. Note the tag name and any other attributes that make it uniquely identifiable.
#
# The two methods we'll be using the most are `.find()` and `.findAll()` (or `find_all()` - different names, same thing). `.find()` returns the first element that matches given arguments; `findAll()` returns a list of all matching elements.

# %%
# we're looking for a div tag. to identify the one we need we need to pass additional attributes dict with its class name
recipe_book = soup.find("div", attrs={"class": "gel-layout gel-layout--equal promo-collection"})

# %% [markdown]
# If you print the `recipe_book` variable you should see just the bit of HTML with all our recipes - no more full page junk! Now we need to find all recipe containers but rather than searching in our soup that contains the full page, let's just look in the `recipe_book`. I did RCI on the individual recipe card to find my container tag and attributes.

# %%
# I used the findAll() method so my result is a list (technically a 'bs4.element.ResultSet' but you can treat it like a list)
recipes = recipe_book.findAll("div", attrs={"class": "gel-layout__item gel-1/2 gel-1/4@xl"})
type(recipes)
# Out:
# bs4.element.ResultSet

# %%
# Let's try to pull some info from an individual recipe
recipe = recipes[0]
title = recipe.find("h3").text  # I can use the .text attribute to pull out text from the tag
# Recipe author info has this annoying "by Joe Bloggs" format. I want just the name, so I'll chain a string .replace() method and get rid of the "by " bit
author = recipe.find("span", attrs={"class": "promo__subtitle gel-long-primer"}).text.replace("by ", "")
url = recipe.find("a")["href"] # some attributes like href (the url reference inside <a> tag) can be accessed via square brackets notation, kind of like a dictionary
print(f"Title: {title}\nAuthor: {author}\nURL: {url}")
# Out:
# Title: Lemon muffins
# Author: Sarah Cook
# URL: /food/recipes/lemon_muffins_01522

# %%
# One thing to note - if you try to access the .text attribute on an element that doesn't exist or can't be found, you'll get an error
recipe.find("span", attrs={"class": "class_that_doesn't_exists"}).text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-87d1ff312f3b> in <module>
#       1 # One thing to note - if you try to access the .text attribute on an element that doesn't exist or can't be found, you'll get an error
# ----> 2 recipe.find("span", attrs={"class": "class_that_doesn't_exists"}).text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
# to make your script error-proof, fist check if the element can be found (i.e. element type is not None) before you try to extract any attributes from it
if recipe.find("span", attrs={"class": "promo__subtitle gel-long-primer"}) is not None:
    author = recipe.find("span", attrs={"class": "promo__subtitle gel-long-primer"}).text

# %% [markdown]
# Now that we know what we're looking for, we can put all of these operations into a loop to extract data from all recipes in our list.

# %%
# we need a master list that will sit outside of our loop
recipes_master = []
for recipe in recipes:
    # we're going to do this for each recipe in our recipes list...
    title = recipe.find("h3").text
    if recipe.find("span", attrs={"class": "promo__subtitle gel-long-primer"}) is not None:
        author = recipe.find("span", attrs={"class": "promo__subtitle gel-long-primer"}).text.replace("by ", "")
    else:
        author = None  # since we're using this variable later, we need to give it some value even if it's None
    url = recipe.find("a")["href"]
    # let's organise our recipe data into a nice dictionary
    recipe_dict = {"title": title,
                  "author": author,
                  "url": url}
    # now we can append it into a master list
    recipes_master.append(recipe_dict)

# let's have a little peek into our master list
recipes_master[:5]
# Out:
# [{'title': 'Lemon muffins',
#   'author': 'Sarah Cook',
#   'url': '/food/recipes/lemon_muffins_01522'},
#  {'title': 'Pumpkin muffins',
#   'author': 'Lorraine Pascale',
#   'url': '/food/recipes/pumpkin_and_rosemary_11109'},
#  {'title': 'Chai muffins',
#   'author': 'Nigella Lawson',
#   'url': '/food/recipes/chai_muffins_06244'},
#  {'title': 'Banana muffins',
#   'author': 'Jill Dupleix',
#   'url': '/food/recipes/bananamuffins_71268'},
#  {'title': 'Healthy banana muffins',
#   'author': 'Fiona Hunter',
#   'url': '/food/recipes/banana_muffins_51549'}]

# %% [markdown]
# Nice! but that's just one page of search results - let's see if we can grab all recipes from all pages. First, we need to know how many pages there are.
#
# There's a lot going on here. I look for all `<a>` tags with the class used by pagination buttons and assign it to `pages_lst`.
# Then I'm using list comprehension to keep it on one line.
# - I want .text for every element (page) of the list
# - but only if .text is not an empty string
# - because I need to convert those numbers stored as strings to integers
# - so that I can get the max value from the list - the total number of pages

# %%
pages_lst = soup.findAll("a", attrs={"class": "pagination__link gel-pica-bold"})
total_pages = max([int(page.text) for page in pages_lst if page.text != ""])
print(f"Total pages: {total_pages}")
# Out:
# Total pages: 3

# %% [markdown]
# Now I can put it all in another loop to cycle through the pages. For each page we'll extract the HTML and run our smaller loop to get all recipes.
#
# I've also extracted the search term just in case I wanted to search for something other than muffins. Remeber that this needs to be url-friendly (i.e. spaces need to be replaced with `%20` etc.) so we'll use the urllib parse module.

# %%
search_term = "muffins"
search_url = parse.quote(search_term)

# %%
# the master list has to be moved outside the big loop, otherwise it would get overwritten with each new page
recipes_master = []

for i in range(0,total_pages):
    # Python is a zero-indexed language so we need to increment our i to start from number 1 rather than 0
    url = f"https://www.bbc.co.uk/food/search?q={search_url}&page={i+1}"
    r = requests.get(url, headers=headers)
    soup = BeautifulSoup(r.content.decode())
    recipe_book = soup.find("div", attrs={"class": "gel-layout gel-layout--equal promo-collection"})
    recipes = recipe_book.findAll("div", attrs={"class": "gel-layout__item gel-1/2 gel-1/4@xl"})
    
    for recipe in recipes:
        title = recipe.find("h3").text
        if recipe.find("span", attrs={"class": "promo__subtitle gel-long-primer"}) is not None:
            author = recipe.find("span", attrs={"class": "promo__subtitle gel-long-primer"}).text.replace("by ", "")
        else:
            author = None
        url = recipe.find("a")["href"]
        recipe_dict = {"title": title,
                      "author": author,
                      "url": url}
        recipes_master.append(recipe_dict)

# %% [markdown]
# We have all recipes with their links in our list, let's put them in a DataFrame

# %%
df = pd.DataFrame(recipes_master)
df.head()
# Out:
#                     title            author  \
# 0           Lemon muffins        Sarah Cook
# 1         Pumpkin muffins  Lorraine Pascale
# 2            Chai muffins    Nigella Lawson
# 3          Banana muffins      Jill Dupleix
# 4  Healthy banana muffins      Fiona Hunter
#
#                                         url
# 0         /food/recipes/lemon_muffins_01522
# 1  /food/recipes/pumpkin_and_rosemary_11109
# 2          /food/recipes/chai_muffins_06244
# 3         /food/recipes/bananamuffins_71268
# 4        /food/recipes/banana_muffins_51549

# %% [markdown]
# ### Next Steps
# What about getting recipe details: ingredients and instructions? We have all the urls and we can use them to loop through individual recipes

# %%
base_url = "https://www.bbc.co.uk"
recipe_urls = df["url"].tolist()
for recipe_url in recipe_urls:
    url = base_url + recipe_url
    # here goes code to scrape the individual recipe page

# %% [markdown]
# ## Scenario 3: reverse-engineering a non-public API.
# On some websites data you see in your browser does not appear in the source code. This is usually because it's being dynamically loaded in via Javascript call to the website's (non-public, as in hidden and undocumented) API. We can figure out how to plug into that kind of API by analysing network call the website makes.
# Let's look at our favourite Verra registry and try to get the CCB data at https://registry.verra.org/app/search/CCB.
#
# ### 1. Inspect network activity
# RCI anywhere on the page and go to the Network tab. Now click on the Search button to load the results. You should see some activity in the network panel.
#
# Find `search?maxResults=2000&$count=true&$skip=0&$top=50` and click on it: in Headers tab / General section you'll see some basic information about the call. We can see the request URL and that the request method was POST. This is different than the previous GET method we were using; we're not just asking for a response, we're sending some data _to_ the API to receive a response. So what are we sending?
#
# Scroll down in the Headers pane to the Request Payload section. This is what we're sending! Click on view source and copy the contents. Now that we have our request URL and the payload we can try and see if the API will give us a correct response.

# %%
url = "https://registry.verra.org/uiapi/resource/resource/search?maxResults=2000&$count=true&$skip=0"
payload = {"program":"CCB",
           "resourceStatuses":
           ["CCB_EX_PROJECT_WITHDRAWN","CCB_EX_UNDER_VALIDATION","CCB_EX_UNDER_VAL_AND_VER","CCB_EX_UNDER_VRF",
            "CCB_EX_VALIDATION_APPROVED","CCB_EX_VALIDATION_EXPIRED","CCB_EX_VRF_APPV_REQUESTED","CCB_EX_VERIFICATION_APPROVED",
            "CCB_EX_VERIFICATION_EXPIRED","CCB_EX_VRF_PBL_CMT_PERIOD_REQ"]}

# %%
# unlike the BBC GET request, we're using a POST request here and passing our payload as the JSON argument
r = requests.post(url, json=payload)
r.status_code
# Out:
# 200

# %%
data = r.json()
data
# Out:
# {'totalCount': 201,
#  'countExceeded': False,
#  '@count': 201,
#  'value': [{'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '142',
#    'resourceName': 'Reforestation of degraded grasslands in Uchindile & Mapanda, Tanzania',
#    'proponent': 'GREEN RESOURCES',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Tanzania',
#    'estAnnualEmissionReductions': 25000,
#    'region': 'Africa',
#    'version': 'CCB Second Edition',
#    'protocols': None},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '514',
#    'resourceName': 'Promoting Sustainable Development through Natural Rubber Tree Plantations in Guatemala',
#    'proponent': 'PICA DE HULE NATURAL, S.A.',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Guatemala',
#    'estAnnualEmissionReductions': 46434,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': ' Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '562',
#    'resourceName': 'The Kasigau Corridor REDD Project – Phase I Rukinga Sanctuary',
#    'proponent': 'Wildlife Works Carbon LLC',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Kenya',
#    'estAnnualEmissionReductions': 251432,
#    'region': 'Africa',
#    'version': 'CCB Second Edition',
#    'protocols': ' Climate Gold, Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '576',
#    'resourceName': 'Restoration of degraded areas and reforestation in Cáceres and Cravo Norte, Colombia',
#    'proponent': 'Asorpar Ltd.',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Colombia',
#    'estAnnualEmissionReductions': 80000,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': None},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '594',
#    'resourceName': 'TIST Program in Kenya, VCS 001',
#    'proponent': 'Clean Air Action Corporation',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Kenya',
#    'estAnnualEmissionReductions': 14701,
#    'region': 'Africa',
#    'version': 'CCB Second Edition',
#    'protocols': ' Community Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '595',
#    'resourceName': 'TIST Program in Kenya, VCS 002',
#    'proponent': 'Clean Air Action Corporation',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Kenya',
#    'estAnnualEmissionReductions': 13663,
#    'region': 'Africa',
#    'version': 'CCB Second Edition',
#    'protocols': ' Community Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '596',
#    'resourceName': 'TIST Program in Kenya, VCS 003',
#    'proponent': 'Clean Air Action Corporation',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Kenya',
#    'estAnnualEmissionReductions': 14482,
#    'region': 'Africa',
#    'version': 'CCB Second Edition',
#    'protocols': ' Community Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '597',
#    'resourceName': 'TIST Program in Kenya, VCS 004',
#    'proponent': 'Clean Air Action Corporation',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Kenya',
#    'estAnnualEmissionReductions': 13790,
#    'region': 'Africa',
#    'version': 'CCB Second Edition',
#    'protocols': ' Community Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '607',
#    'resourceName': 'Darkwoods Forest Carbon Project',
#    'proponent': 'Nature Conservancy of Canada',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Improved Forest Management',
#    'resourceStatus': 'Verification approved',
#    'country': 'Canada',
#    'estAnnualEmissionReductions': 124847,
#    'region': 'North America',
#    'version': 'CCB Second Edition',
#    'protocols': ' Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '612',
#    'resourceName': 'The Kasigau Corridor REDD Project - Phase II The Community Ranches',
#    'proponent': 'Wildlife Works Carbon LLC',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Kenya',
#    'estAnnualEmissionReductions': 1614959,
#    'region': 'Africa',
#    'version': 'CCB Second Edition',
#    'protocols': ' Climate Gold, Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '647',
#    'resourceName': 'Boden Creek Ecological Preserve Forest Carbon Project',
#    'proponent': 'Boden Creek Ecological Preserve',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Validation expired',
#    'country': 'Belize',
#    'estAnnualEmissionReductions': 57718,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': ' Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '658',
#    'resourceName': 'Reforestation of pastures in Campo Verde with native species, Pucallpa, Peru',
#    'proponent': 'Bosques Amazónicos',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Validation expired',
#    'country': 'Peru',
#    'estAnnualEmissionReductions': 5600,
#    'region': 'Latin America',
#    'version': 'CCB First Edition',
#    'protocols': None},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '665',
#    'resourceName': 'Multi-Species Reforestation in Mato Grosso, Brazil',
#    'proponent': 'ONF International',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Project withdrawn',
#    'country': 'Brazil',
#    'estAnnualEmissionReductions': 15512,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': ' Silver'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '673',
#    'resourceName': 'Natural High Forest Rehabilitation Project on degraded land of Kibale National Park',
#    'proponent': 'Greenchoice',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Uganda',
#    'estAnnualEmissionReductions': 74181,
#    'region': 'Africa',
#    'version': 'CCB Third Edition',
#    'protocols': ' Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '674',
#    'resourceName': 'Rimba Raya Biodiversity Reserve Project',
#    'proponent': 'InfiniteEARTH',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approval requested\xa0',
#    'country': 'Indonesia',
#    'estAnnualEmissionReductions': 3527171,
#    'region': 'Oceania',
#    'version': 'CCB Second Edition',
#    'protocols': ' Climate Gold, Community Gold, Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '689',
#    'resourceName': 'Reforestation of degraded land in Chhattisgarh, India',
#    'proponent': 'Prakash Industries Limited',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Validation expired',
#    'country': 'India',
#    'estAnnualEmissionReductions': 5007,
#    'region': 'Asia',
#    'version': 'CCB First Edition',
#    'protocols': None},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '737',
#    'resourceName': 'TIST Program in Kenya, VCS 005',
#    'proponent': 'Clean Air Action Corporation',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Kenya',
#    'estAnnualEmissionReductions': 86694,
#    'region': 'Africa',
#    'version': 'CCB Third Edition',
#    'protocols': ' Community Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '738',
#    'resourceName': 'Carbon Project in the Emas-Taquari Biodiversity Corridor, Goiás and Mato Grosso do Sul, Brazil',
#    'proponent': 'Oreades Nucelo de Geoprocessamento',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Brazil',
#    'estAnnualEmissionReductions': 6870,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': ' Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '796',
#    'resourceName': 'Alto Huayabamba',
#    'proponent': 'Pur Projet',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Validation approved',
#    'country': 'Peru',
#    'estAnnualEmissionReductions': 28756,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': ' Community Gold, Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '812',
#    'resourceName': 'Bull Run Overseas Forest Carbon Project',
#    'proponent': 'Bull Run Overseas Ltd.',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Validation expired',
#    'country': 'Belize',
#    'estAnnualEmissionReductions': 12315,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': ' Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '818',
#    'resourceName': 'Protection of the Bolivian Amazon Forest',
#    'proponent': 'Fermin Aldabe',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Validation expired',
#    'country': 'Bolivia',
#    'estAnnualEmissionReductions': 5885,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': ' Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '824',
#    'resourceName': 'TIST Program in Uganda, VCS 001',
#    'proponent': 'Clean Air Action Corporation',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Uganda',
#    'estAnnualEmissionReductions': 24348,
#    'region': 'Africa',
#    'version': 'CCB Second Edition',
#    'protocols': ' Community Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '825',
#    'resourceName': 'TIST Program in Uganda, VCS 002',
#    'proponent': 'Clean Air Action Corporation',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Uganda',
#    'estAnnualEmissionReductions': 4801,
#    'region': 'Africa',
#    'version': 'CCB Second Edition',
#    'protocols': ' Community Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '826',
#    'resourceName': 'TIST Program in Uganda, VCS 004',
#    'proponent': 'Clean Air Action Corporation',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Uganda',
#    'estAnnualEmissionReductions': 2958,
#    'region': 'Africa',
#    'version': 'CCB Second Edition',
#    'protocols': ' Community Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '827',
#    'resourceName': 'TIST Program in Uganda, VCS 003',
#    'proponent': 'Clean Air Action Corporation',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Uganda',
#    'estAnnualEmissionReductions': 13112,
#    'region': 'Africa',
#    'version': 'CCB Second Edition',
#    'protocols': ' Community Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '838',
#    'resourceName': 'Tensas River Basin Project',
#    'proponent': 'The Nature Conservancy',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Validation expired',
#    'country': 'United States',
#    'estAnnualEmissionReductions': 1196,
#    'region': 'North America',
#    'version': 'CCB First Edition',
#    'protocols': None},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '844',
#    'resourceName': 'Madre de Dios Amazon REDD Project',
#    'proponent': 'Multiple Proponents',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Peru',
#    'estAnnualEmissionReductions': 659793,
#    'region': 'Latin America',
#    'version': 'CCB First Edition',
#    'protocols': ' Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '856',
#    'resourceName': 'The Chocó-Darién Conservation Corridor REDD Project',
#    'proponent': 'Anthrotect S.A.S.',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Colombia',
#    'estAnnualEmissionReductions': 96,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': ' Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '868',
#    'resourceName': 'REDD project in Brazil nut concessions in Madre de Dios, Peru',
#    'proponent': 'Bosques Amazónicos',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Validation expired',
#    'country': 'Peru',
#    'estAnnualEmissionReductions': 2086089,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': ' Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '899',
#    'resourceName': 'TIST Program in Kenya, VCS 006',
#    'proponent': 'Clean Air Action Corporation',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Kenya',
#    'estAnnualEmissionReductions': 233275,
#    'region': 'Africa',
#    'version': 'CCB Second Edition',
#    'protocols': ' Community Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '902',
#    'resourceName': 'KARIBA REDD+ PROJECT',
#    'proponent': 'Carbon Green Investments (Guernsey)',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Zimbabwe',
#    'estAnnualEmissionReductions': 6550464,
#    'region': 'Africa',
#    'version': 'CCB Second Edition',
#    'protocols': ' Climate Gold, Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '904',
#    'resourceName': 'Reduced Emissions from Deforestation and Degradation in Community Forests – Oddar Meanchey, Cambodia',
#    'proponent': 'Royal Government of Cambodia-Forestry Admin',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification expired',
#    'country': 'Cambodia',
#    'estAnnualEmissionReductions': 204792,
#    'region': 'Asia',
#    'version': 'CCB Second Edition',
#    'protocols': ' Climate Gold, Community Gold, Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '934',
#    'resourceName': 'The Mai Ndombe REDD+ Project',
#    'proponent': 'Wildlife Works Carbon LLC',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Congo, The Democratic Republic of The',
#    'estAnnualEmissionReductions': 5671613,
#    'region': 'Africa',
#    'version': 'CCB Second Edition',
#    'protocols': ' Climate Gold, Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '944',
#    'resourceName': 'Alto Mayo Conservation Initiative',
#    'proponent': 'Conservation International Foundation',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Peru',
#    'estAnnualEmissionReductions': 515268,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': ' Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '953',
#    'resourceName': 'The Paraguay Forest Conservation Project - Reduction of GHG emissions from deforestation and forest degradation in the Chaco-Pantanal ecosystem',
#    'proponent': 'Swire Pacific Offshore Operations (Pte) Ltd. (SPO)',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Paraguay',
#    'estAnnualEmissionReductions': 12784,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': ' Climate Gold, Community Gold, Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '958',
#    'resourceName': 'BIOCORREDOR MARTIN SAGRADO REDD+ PROJECT',
#    'proponent': 'Pur Projet',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Peru',
#    'estAnnualEmissionReductions': 219722,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': ' Climate Gold, Community Gold, Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '959',
#    'resourceName': '‘Guanaré’ Forest Plantations on degraded grasslands under extensive grazing',
#    'proponent': 'Guanaré SA',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Under validation and verification',
#    'country': 'Uruguay',
#    'estAnnualEmissionReductions': 127416,
#    'region': 'Latin America',
#    'version': 'CCB Third Edition',
#    'protocols': ' Silver'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '963',
#    'resourceName': 'The Purus Project',
#    'proponent': 'Multiple Proponents',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Under Verification',
#    'country': 'Brazil',
#    'estAnnualEmissionReductions': 89868,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': ' Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '977',
#    'resourceName': 'RMDLT Portel - Pará REDD Project',
#    'proponent': 'RMDLT Property Group Ltd.',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification public comment period requested\xa0',
#    'country': 'Brazil',
#    'estAnnualEmissionReductions': 553273,
#    'region': 'Latin America',
#    'version': 'CCB Third Edition',
#    'protocols': ' Climate Gold, Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '981',
#    'resourceName': 'ADPML PORTEL-PARA REDD PROJECT',
#    'proponent': 'Avoided Deforestation Project (Manaus) Limited (“A',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Validation expired',
#    'country': 'Brazil',
#    'estAnnualEmissionReductions': 264116,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': ' Climate Gold, Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '985',
#    'resourceName': 'Cordillera Azul National Park REDD Project',
#    'proponent': 'CIMA, Cordillera Azul',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Peru',
#    'estAnnualEmissionReductions': 1575268,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': ' Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '993',
#    'resourceName': 'TIST Program in Uganda, VCS 005',
#    'proponent': 'Clean Air Action Corporation',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Uganda',
#    'estAnnualEmissionReductions': 19342,
#    'region': 'Africa',
#    'version': 'CCB Second Edition',
#    'protocols': ' Community Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '994',
#    'resourceName': 'TIST Program in India, VCS 001',
#    'proponent': 'Clean Air Action Corporation',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'India',
#    'estAnnualEmissionReductions': 11047,
#    'region': 'Asia',
#    'version': 'CCB Third Edition',
#    'protocols': None},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '995',
#    'resourceName': 'TIST Program in Uganda, VCS 006',
#    'proponent': 'Clean Air Action Corporation',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Uganda',
#    'estAnnualEmissionReductions': 7787,
#    'region': 'Africa',
#    'version': 'CCB Second Edition',
#    'protocols': ' Community Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '996',
#    'resourceName': 'TIST Program in Kenya, VCS 009',
#    'proponent': 'Clean Air Action Corporation',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Kenya',
#    'estAnnualEmissionReductions': 88163,
#    'region': 'Africa',
#    'version': 'CCB Second Edition',
#    'protocols': ' Community Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1015',
#    'resourceName': 'Community-based reforestation project on degraded lands in Uttar Pradesh, India by Indian Farm Forestry Development Co-operative Limited',
#    'proponent': 'Indian Farm Forestry Development Co-operative LTD',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Project withdrawn',
#    'country': 'India',
#    'estAnnualEmissionReductions': 5651,
#    'region': 'Asia',
#    'version': 'CCB First Edition',
#    'protocols': None},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1047',
#    'resourceName': 'Carbon Emissions Reduction Project in the Forest Corridor Ambositra-Vondrozo (COFAV), Madagascar',
#    'proponent': 'Govt. of Madagascar, Direction Generale des Forets',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Validation approved',
#    'country': 'Madagascar',
#    'estAnnualEmissionReductions': 220965,
#    'region': 'Africa',
#    'version': 'CCB Second Edition',
#    'protocols': ' Climate Gold, Community Gold, Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1067',
#    'resourceName': 'Reduction of deforestation and degradation in Tambopata National Reserve and Bahuaja-Sonene National Park within the area of Madre de Dios region –Peru',
#    'proponent': 'AIDER',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Under Verification',
#    'country': 'Peru',
#    'estAnnualEmissionReductions': 457750,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': ' Climate Gold, Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1080',
#    'resourceName': 'Reforestation with Native Species in the Pachijal and Mira River Watersheds for Carbon Retention',
#    'proponent': 'Multiple Proponents',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Validation expired',
#    'country': 'Ecuador',
#    'estAnnualEmissionReductions': 6973,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': ' Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1085',
#    'resourceName': 'ECOPLANET BAMBOO CENTRAL AMERICA',
#    'proponent': 'EcoPlanet Bamboo Group LLC',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Validation expired',
#    'country': 'Nicaragua',
#    'estAnnualEmissionReductions': 40815,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': ' Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1112',
#    'resourceName': 'The Russas Project',
#    'proponent': 'Multiple Proponents',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Brazil',
#    'estAnnualEmissionReductions': 120147,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': ' Community Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1113',
#    'resourceName': 'The Valparaiso Project',
#    'proponent': 'Multiple Proponents',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Under Verification',
#    'country': 'Brazil',
#    'estAnnualEmissionReductions': 153853,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': ' Community Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1115',
#    'resourceName': 'JARI/AMAPÁ REDD+ PROJECT',
#    'proponent': 'Multiple Proponents',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification public comment period requested\xa0',
#    'country': 'Brazil',
#    'estAnnualEmissionReductions': 115009,
#    'region': 'Latin America',
#    'version': 'CCB Third Edition',
#    'protocols': ' Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1118',
#    'resourceName': 'Suruí Forest Carbon Project',
#    'proponent': "Metareilá Association of the Suruí Indigenous P'pl",
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Validation expired',
#    'country': 'Brazil',
#    'estAnnualEmissionReductions': 247460,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': ' Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1122',
#    'resourceName': 'April Salumei REDD Project',
#    'proponent': 'Rainforest Project Management Limited',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Validation expired',
#    'country': 'Papua New Guinea',
#    'estAnnualEmissionReductions': 1032650,
#    'region': 'Oceania',
#    'version': 'CCB Second Edition',
#    'protocols': ' Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1133',
#    'resourceName': 'Yacumama Forest Carbon Project',
#    'proponent': 'YACUMAMA S.R.L.',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Project withdrawn',
#    'country': 'Peru',
#    'estAnnualEmissionReductions': 72982,
#    'region': 'Latin America',
#    'version': 'CCB Third Edition',
#    'protocols': None},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1147',
#    'resourceName': 'Amazon Rio REDD+ IFM',
#    'proponent': 'Empresa Brasileira de Conservação de Florestas S.A',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Under validation and verification',
#    'country': 'Brazil',
#    'estAnnualEmissionReductions': 61238,
#    'region': 'Latin America',
#    'version': 'CCB Third Edition',
#    'protocols': ' Silver'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1168',
#    'resourceName': 'Kulera Landscape REDD+ Program for Co-Managed Protected Areas, Malawi',
#    'proponent': 'Multiple Proponents',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Malawi',
#    'estAnnualEmissionReductions': 210421,
#    'region': 'Africa',
#    'version': 'CCB Second Edition',
#    'protocols': ' Climate Gold, Community Gold, Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1175',
#    'resourceName': 'AVOIDING PLANNED DEFORESTATION AND DEGRADATION IN THE VALDIVIAN COASTAL RESERVE, CHILE',
#    'proponent': 'The Nature Conservancy',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Chile',
#    'estAnnualEmissionReductions': 58154,
#    'region': 'Latin America',
#    'version': 'CCB Third Edition',
#    'protocols': ' Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1201',
#    'resourceName': 'Gola REDD project',
#    'proponent': 'Gola Rainforest Conservation LG',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Sierra Leone',
#    'estAnnualEmissionReductions': 498667,
#    'region': 'Africa',
#    'version': 'CCB Second Edition',
#    'protocols': ' Climate Gold, Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1202',
#    'resourceName': 'LOWER ZAMBEZI REDD+ PROJECT',
#    'proponent': 'BioCarbon Partners',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Zambia',
#    'estAnnualEmissionReductions': 210316,
#    'region': 'Africa',
#    'version': 'CCB Second Edition',
#    'protocols': ' Climate Gold, Community Gold, Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1215',
#    'resourceName': 'The Makira Forest Protected Area in Madagascar',
#    'proponent': 'The Wildlife Conservation Society (WCS)',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Madagascar',
#    'estAnnualEmissionReductions': 1267231,
#    'region': 'Africa',
#    'version': 'CCB Second Edition',
#    'protocols': ' Climate Gold, Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1218',
#    'resourceName': 'Evio Kuiñaji Ese´Eja Cuana, To Mitigate Climate Change, Madre de Dios - Perú',
#    'proponent': 'Multiple Proponents',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Under Verification',
#    'country': 'Peru',
#    'estAnnualEmissionReductions': 114410,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': ' Climate Gold, Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1233',
#    'resourceName': 'Reforestation with Rubber on degraded lands of Colombia',
#    'proponent': 'Compañía de Profesionales de Bolsa S.A (PdB)',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Project withdrawn',
#    'country': 'Colombia',
#    'estAnnualEmissionReductions': 38946,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': None},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1285',
#    'resourceName': 'New Leaf Carbon Project',
#    'proponent': 'Tasmanian Land Conservancy',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Improved Forest Management',
#    'resourceStatus': 'Verification approved',
#    'country': 'Australia',
#    'estAnnualEmissionReductions': 43106,
#    'region': 'Oceania',
#    'version': 'CCB Second Edition',
#    'protocols': ' Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1317',
#    'resourceName': 'Reforestation Grouped Project at Pratigi Environmental Protection Area',
#    'proponent': 'Land Conservation Organization (OCT)',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Brazil',
#    'estAnnualEmissionReductions': 1636,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': ' Climate Gold, Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1325',
#    'resourceName': 'Mjumita Community Forest Project (Lindi)',
#    'proponent': 'Multiple Proponents',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Tanzania',
#    'estAnnualEmissionReductions': 46263,
#    'region': 'Africa',
#    'version': 'CCB Third Edition',
#    'protocols': ' Climate Gold, Community Gold, Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1326',
#    'resourceName': 'Laguna Seca Forest Carbon Project',
#    'proponent': 'The Forestlands Group LLC',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Validation approved',
#    'country': 'Belize',
#    'estAnnualEmissionReductions': 255935,
#    'region': 'Latin America',
#    'version': 'CCB Third Edition',
#    'protocols': ' Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1329',
#    'resourceName': 'Maísa REDD+ Project',
#    'proponent': 'Multiple Proponents',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Validation approved',
#    'country': 'Brazil',
#    'estAnnualEmissionReductions': 67458,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': ' Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1332',
#    'resourceName': 'Reforestation Project in Yingjing County, Sichuan Province',
#    'proponent': 'Multiple Proponents',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'China',
#    'estAnnualEmissionReductions': 3365,
#    'region': 'Asia',
#    'version': 'CCB Second Edition',
#    'protocols': None},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1340',
#    'resourceName': 'Bale Mountains Eco-region REDD+ project',
#    'proponent': 'Oromia Forest and Wildlife Enterprise',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Ethiopia',
#    'estAnnualEmissionReductions': 1288821,
#    'region': 'Africa',
#    'version': 'CCB Third Edition',
#    'protocols': ' Climate Gold, Community Gold, Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1343',
#    'resourceName': 'Kuzuko Lodge Private Game Reserve thicket restoration project',
#    'proponent': 'Spekboom Trading (Pty) Ltd',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Validation expired',
#    'country': 'South Africa',
#    'estAnnualEmissionReductions': 44206,
#    'region': 'Africa',
#    'version': 'CCB Second Edition',
#    'protocols': ' Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1351',
#    'resourceName': 'Planting for the Future: Financially sustainable agroforestry systems and payments for ecosystem services',
#    'proponent': 'Plant your Future',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Validation approved',
#    'country': 'Peru',
#    'estAnnualEmissionReductions': 719,
#    'region': 'Latin America',
#    'version': 'CCB Third Edition',
#    'protocols': ' Climate Gold, Community Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1359',
#    'resourceName': 'Isangi REDD+ Project',
#    'proponent': 'SAFBOIS, SPRL',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Under Verification',
#    'country': 'Congo, The Democratic Republic of The',
#    'estAnnualEmissionReductions': 324534,
#    'region': 'Africa',
#    'version': 'CCB Second Edition',
#    'protocols': ' Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1360',
#    'resourceName': 'Forest Management to reduce deforestation and degradation in Shipibo Conibo and Cacataibo Indigenous communities of Ucayali region',
#    'proponent': 'Multiple Proponents',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approval requested\xa0',
#    'country': 'Peru',
#    'estAnnualEmissionReductions': 564818,
#    'region': 'Latin America',
#    'version': 'CCB Third Edition',
#    'protocols': ' Climate Gold, Community Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1381',
#    'resourceName': 'HIMA (Hifadhi ya Misitu ya Asili ya jamii) REDD+ Program',
#    'proponent': 'Multiple Proponents',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Under validation and verification',
#    'country': 'Tanzania',
#    'estAnnualEmissionReductions': 244000,
#    'region': 'Africa',
#    'version': 'CCB Third Edition',
#    'protocols': ' Climate Gold, Community Gold, Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1382',
#    'resourceName': 'The Envira Amazonia Project - A Tropical Forest Conservation Project in Acre, Brazil',
#    'proponent': 'Multiple Proponents',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Brazil',
#    'estAnnualEmissionReductions': 1259646,
#    'region': 'Latin America',
#    'version': 'CCB Third Edition',
#    'protocols': ' Climate Gold, Community Gold, Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1384',
#    'resourceName': 'Reduced Emissions from Avoided Deforestation in the Multiple Use Zone of the Maya Biosphere Reserve in Guatemala (GuateCarbon)',
#    'proponent': 'Consejo Nacional de Áreas Protegidas (CONAP)',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Guatemala',
#    'estAnnualEmissionReductions': 1385971,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': ' Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1389',
#    'resourceName': 'Acapa -\xad Bajo Mira Y Frontera REDD+ Project',
#    'proponent': 'Multiple Proponents',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Colombia',
#    'estAnnualEmissionReductions': 404786,
#    'region': 'Latin America',
#    'version': 'CCB Third Edition',
#    'protocols': ' Community Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1390',
#    'resourceName': 'Carmen del Darién (CDD) REDD+ Project',
#    'proponent': 'Multiple Proponents',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Colombia',
#    'estAnnualEmissionReductions': 462190,
#    'region': 'Latin America',
#    'version': 'CCB Third Edition',
#    'protocols': ' Community Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1391',
#    'resourceName': 'SIVIRÚ-USARAGÁ-PIZARRO-PILIZÁ (SUPP) REDD+ Project',
#    'proponent': 'Multiple Proponents',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Colombia',
#    'estAnnualEmissionReductions': 312078,
#    'region': 'Latin America',
#    'version': 'CCB Third Edition',
#    'protocols': ' Community Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1392',
#    'resourceName': 'Cajambre REDD+ Project',
#    'proponent': 'Consejo Comunitario de Cajambre',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Colombia',
#    'estAnnualEmissionReductions': 297488,
#    'region': 'Latin America',
#    'version': 'CCB Third Edition',
#    'protocols': ' Community Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1395',
#    'resourceName': 'Bajo Calima y Bahía Málaga (BCBM) REDD+ Project',
#    'proponent': 'Multiple Proponents',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Colombia',
#    'estAnnualEmissionReductions': 498719,
#    'region': 'Latin America',
#    'version': 'CCB Third Edition',
#    'protocols': ' Community Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1396',
#    'resourceName': 'Rio Pepe y ACABA REDD+ Project',
#    'proponent': 'Multiple Proponents',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Colombia',
#    'estAnnualEmissionReductions': 224050,
#    'region': 'Latin America',
#    'version': 'CCB First Edition',
#    'protocols': ' Community Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1399',
#    'resourceName': 'Mutatá REDD+ Project',
#    'proponent': 'Cabildo Mayor Indígena de Mutatá',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Colombia',
#    'estAnnualEmissionReductions': 156476,
#    'region': 'Latin America',
#    'version': 'CCB Third Edition',
#    'protocols': ' Community Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1400',
#    'resourceName': 'Concosta REDD+ Project',
#    'proponent': 'Consejo Comunitario de Concosta',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Verification approved',
#    'country': 'Colombia',
#    'estAnnualEmissionReductions': 333978,
#    'region': 'Latin America',
#    'version': 'CCB Third Edition',
#    'protocols': ' Community Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1403',
#    'resourceName': 'The Paraguay Forest Conservation Project – Reduction of GHG Emissions from Deforestation and Forest Degradation in the Parana Atlantic Ecosystem – Forest Protection in the La Amistad Community, San Rafael',
#    'proponent': 'Swire Pacific Offshore Operations (Pte) Ltd. (SPO)',
#    'operator': None,
#    'designee': None,
# ...
#    'proponent': 'Asociación Amazónicos por la Amazonía – AMPA',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Under Verification',
#    'country': 'Peru',
#    'estAnnualEmissionReductions': 52425,
#    'region': 'Latin America',
#    'version': 'CCB Second Edition',
#    'protocols': ' Community Gold, Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1799',
#    'resourceName': 'Forest management to mitigate climate change in Bélgica native community, Madre de Dios region – Peru',
#    'proponent': 'Multiple Proponents',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Under validation',
#    'country': 'Peru',
#    'estAnnualEmissionReductions': 126168,
#    'region': 'Latin America',
#    'version': 'CCB First Edition',
#    'protocols': None},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1806',
#    'resourceName': 'Riscales REDD+ Project',
#    'proponent': 'CONSEJO COMUNITARIO GENERAL LOS RISCALES',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Under validation',
#    'country': 'Colombia',
#    'estAnnualEmissionReductions': 187240,
#    'region': 'Latin America',
#    'version': 'CCB Third Edition',
#    'protocols': None},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1811',
#    'resourceName': 'Jari/Pará REDD+ Project',
#    'proponent': 'Multiple Proponents',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Validation approved',
#    'country': 'Brazil',
#    'estAnnualEmissionReductions': 525314,
#    'region': 'Latin America',
#    'version': 'CCB Third Edition',
#    'protocols': ' Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1821',
#    'resourceName': "Conservación de los Ecosistemas y el Almacén de Carbono Región de Transición Guayano Amazónica 'Flor de Inírida'",
#    'proponent': 'Ciprogress Greenlife',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Under validation',
#    'country': 'Colombia',
#    'estAnnualEmissionReductions': 7627523,
#    'region': None,
#    'version': 'CCB Third Edition',
#    'protocols': None},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1825',
#    'resourceName': 'Afforestation Project in Xining City',
#    'proponent': 'Qinghai Forestry Ecological Construction and Investment Co., Ltd.',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'China',
#    'estAnnualEmissionReductions': 499982,
#    'region': 'Asia',
#    'version': 'CCB Third Edition',
#    'protocols': ' Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1826',
#    'resourceName': 'Qinghai Afforestation Project',
#    'proponent': 'Qinghai Forestry Ecological Construction and Investment Co., Ltd.',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'China',
#    'estAnnualEmissionReductions': 766948,
#    'region': 'Asia',
#    'version': 'CCB Third Edition',
#    'protocols': ' Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1832',
#    'resourceName': 'Haidong Afforestation Project',
#    'proponent': 'Qinghai Forestry Ecological Construction and Investment Co., Ltd.',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'China',
#    'estAnnualEmissionReductions': 598145,
#    'region': 'Asia',
#    'version': 'CCB Third Edition',
#    'protocols': ' Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1847',
#    'resourceName': 'Qianxinan Afforestation Project in Guizhou Province',
#    'proponent': 'Guizhou Baiheng Fertiliser Co., Ltd',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'China',
#    'estAnnualEmissionReductions': 469669,
#    'region': 'Asia',
#    'version': 'CCB Third Edition',
#    'protocols': ' Climate Gold, Community Gold, Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1848',
#    'resourceName': 'Korea - Myanmar Joint - Bago District REDD+ Program, with North Zamari Wildlife Sanctuary',
#    'proponent': 'Multiple Proponents',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Under validation',
#    'country': 'Myanmar',
#    'estAnnualEmissionReductions': 238397,
#    'region': 'Asia',
#    'version': 'CCB Third Edition',
#    'protocols': None},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1855',
#    'resourceName': 'Hechu Afforestation Project in Anhui Province',
#    'proponent': 'Hefei Zhuoya Landscaping Engineering Co., Ltd.',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'China',
#    'estAnnualEmissionReductions': 469187,
#    'region': 'Asia',
#    'version': 'CCB Third Edition',
#    'protocols': ' Silver'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1864',
#    'resourceName': 'Puzhen Afforestation Project in Guizhou Province',
#    'proponent': 'Guizhou Baiheng Fertiliser Co., Ltd',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approval requested\xa0',
#    'country': 'China',
#    'estAnnualEmissionReductions': 313023,
#    'region': 'Asia',
#    'version': 'CCB Third Edition',
#    'protocols': ' Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1865',
#    'resourceName': 'Xiguan Afforestation Project in Guizhou Province',
#    'proponent': 'Guizhou Baiheng Fertiliser Co., Ltd',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'China',
#    'estAnnualEmissionReductions': 388420,
#    'region': 'Asia',
#    'version': 'CCB Third Edition',
#    'protocols': ' Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1866',
#    'resourceName': 'XinJiang Makit County Afforestation Carbon Sequestration Project',
#    'proponent': 'Makit Base Junlian Cotton Industry Co., Ltd.',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approved',
#    'country': 'China',
#    'estAnnualEmissionReductions': 90393,
#    'region': 'Asia',
#    'version': 'CCB Third Edition',
#    'protocols': ' Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1895',
#    'resourceName': 'Jilin Linjiang Afforestation Project',
#    'proponent': 'Jilin Forest Industry Environmental Technology Co., Ltd.',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Under validation',
#    'country': 'China',
#    'estAnnualEmissionReductions': 546751,
#    'region': 'Asia',
#    'version': 'CCB Third Edition',
#    'protocols': ' Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1896',
#    'resourceName': 'Hunan Northern and Northwestern Area Afforestation Project',
#    'proponent': 'Jilin Forest Industry Environmental Technology Co., Ltd.',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Under validation',
#    'country': 'China',
#    'estAnnualEmissionReductions': 286518,
#    'region': 'Asia',
#    'version': 'CCB Third Edition',
#    'protocols': ' Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1897',
#    'resourceName': 'Ntakata Mountains REDD',
#    'proponent': 'Carbon Tanzania',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Under validation',
#    'country': 'Tanzania',
#    'estAnnualEmissionReductions': 420200,
#    'region': 'Africa',
#    'version': 'CCB Third Edition',
#    'protocols': None},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1899',
#    'resourceName': 'Sumatra Merang Peatland Project (SMPP)',
#    'proponent': 'Multiple Proponents',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Wetland Rewetting and Conservation',
#    'resourceStatus': 'Under Verification',
#    'country': 'Indonesia',
#    'estAnnualEmissionReductions': 1338569,
#    'region': 'Asia',
#    'version': 'CCB First Edition',
#    'protocols': None},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1900',
#    'resourceName': 'Makame Savannah REDD',
#    'proponent': 'Carbon Tanzania',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Under validation',
#    'country': 'Tanzania',
#    'estAnnualEmissionReductions': 136411,
#    'region': 'Africa',
#    'version': 'CCB First Edition',
#    'protocols': None},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1953',
#    'resourceName': 'The ARC REDD+ Project',
#    'proponent': 'Amazon Reforestation Consortium',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Under validation',
#    'country': 'Brazil',
#    'estAnnualEmissionReductions': 340000,
#    'region': 'Latin America',
#    'version': 'CCB Third Edition',
#    'protocols': ' Climate Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '1969',
#    'resourceName': 'The ARC A/R Project',
#    'proponent': 'Amazon Reforestation Consortium',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Under validation and verification',
#    'country': 'Brazil',
#    'estAnnualEmissionReductions': 516780,
#    'region': 'Latin America',
#    'version': 'CCB Third Edition',
#    'protocols': ' Silver'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '2070',
#    'resourceName': 'Guinan Afforestation Project',
#    'proponent': 'Guizhou Baiheng Fertiliser Co., Ltd',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Verification approval requested\xa0',
#    'country': 'China',
#    'estAnnualEmissionReductions': 645768,
#    'region': 'Asia',
#    'version': 'CCB Third Edition',
#    'protocols': ' Silver'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '2082',
#    'resourceName': 'Qianbei Afforestation Project',
#    'proponent': 'Guizhou Xinzhanxin Agricultural Technology Co., Ltd.',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Under validation',
#    'country': 'China',
#    'estAnnualEmissionReductions': 708123,
#    'region': 'Asia',
#    'version': 'CCB First Edition',
#    'protocols': ' Silver'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '2083',
#    'resourceName': 'Liangdu Afforestation Project',
#    'proponent': 'Guizhou Xinzhanxin Agricultural Technology Co., Ltd.',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Validation approved',
#    'country': 'China',
#    'estAnnualEmissionReductions': 336390,
#    'region': 'Asia',
#    'version': 'CCB First Edition',
#    'protocols': None},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '2087',
#    'resourceName': 'Chudu Afforestation Project',
#    'proponent': 'Xichuan Rongda Agriculture and Forestry Co., Ltd',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Validation approved',
#    'country': 'China',
#    'estAnnualEmissionReductions': 668883,
#    'region': 'Asia',
#    'version': 'CCB First Edition',
#    'protocols': None},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '2252',
#    'resourceName': 'Rio Anapu-Pacaja REDD Project',
#    'proponent': 'Brazil AgFor LLC',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Under validation and verification',
#    'country': 'Brazil',
#    'estAnnualEmissionReductions': 938000,
#    'region': 'Latin America',
#    'version': 'CCB First Edition',
#    'protocols': ' Climate Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '2278',
#    'resourceName': 'The Jaguar Amazon REDD Project',
#    'proponent': 'Greenoxx NGO',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#    'resourceStatus': 'Under validation',
#    'country': 'Peru',
#    'estAnnualEmissionReductions': 3751851,
#    'region': 'Latin America',
#    'version': 'CCB Third Edition',
#    'protocols': ' Biodiversity Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '2301',
#    'resourceName': 'Zhangjiakou Chongli Afforestation Project in Hebei Province',
#    'proponent': 'Zhangjiakou Sailin Landscaping Co., Ltd.',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Under validation',
#    'country': 'China',
#    'estAnnualEmissionReductions': 97103,
#    'region': 'Asia',
#    'version': 'CCB Third Edition',
#    'protocols': ' Gold'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '2305',
#    'resourceName': 'Zhangjiakou Yuxian Afforestation Project in Hebei Province',
#    'proponent': 'Zhangjiakou Sailin Landscaping Co., Ltd.',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Under validation',
#    'country': 'China',
#    'estAnnualEmissionReductions': 70374,
#    'region': 'Asia',
#    'version': 'CCB Third Edition',
#    'protocols': ' Silver'},
#   {'program': 'Climate, Community, and Biodiversity Standards',
#    'resourceIdentifier': '2310',
#    'resourceName': 'Anhuang Afforestation Project',
#    'proponent': 'Guizhou Xinzhanxin Agricultural Technology Co., Ltd.',
#    'operator': None,
#    'designee': None,
#    'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#    'resourceStatus': 'Under validation',
#    'country': 'China',
#    'estAnnualEmissionReductions': 607596,
#    'region': 'Asia',
#    'version': 'CCB Third Edition',
#    'protocols': None}]}

# %%
# Our juicy projects data is a list within the 'value' key. Let's have a look at the first 3 projects
data["value"][:3]
# Out:
# [{'program': 'Climate, Community, and Biodiversity Standards',
#   'resourceIdentifier': '142',
#   'resourceName': 'Reforestation of degraded grasslands in Uchindile & Mapanda, Tanzania',
#   'proponent': 'GREEN RESOURCES',
#   'operator': None,
#   'designee': None,
#   'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#   'resourceStatus': 'Verification approved',
#   'country': 'Tanzania',
#   'estAnnualEmissionReductions': 25000,
#   'region': 'Africa',
#   'version': 'CCB Second Edition',
#   'protocols': None},
#  {'program': 'Climate, Community, and Biodiversity Standards',
#   'resourceIdentifier': '514',
#   'resourceName': 'Promoting Sustainable Development through Natural Rubber Tree Plantations in Guatemala',
#   'proponent': 'PICA DE HULE NATURAL, S.A.',
#   'operator': None,
#   'designee': None,
#   'protocolCategories': 'Afforestation, Reforestation and Revegetation',
#   'resourceStatus': 'Verification approved',
#   'country': 'Guatemala',
#   'estAnnualEmissionReductions': 46434,
#   'region': 'Latin America',
#   'version': 'CCB Second Edition',
#   'protocols': ' Biodiversity Gold'},
#  {'program': 'Climate, Community, and Biodiversity Standards',
#   'resourceIdentifier': '562',
#   'resourceName': 'The Kasigau Corridor REDD Project – Phase I Rukinga Sanctuary',
#   'proponent': 'Wildlife Works Carbon LLC',
#   'operator': None,
#   'designee': None,
#   'protocolCategories': 'Reduced Emissions from Deforestation and Degradation',
#   'resourceStatus': 'Verification approved',
#   'country': 'Kenya',
#   'estAnnualEmissionReductions': 251432,
#   'region': 'Africa',
#   'version': 'CCB Second Edition',
#   'protocols': ' Climate Gold, Biodiversity Gold'}]

# %%
# Now we can make a dataframe from it
df = pd.DataFrame(data["value"])
df.head()
# Out:
#                                           program resourceIdentifier  \
# 0  Climate, Community, and Biodiversity Standards                142
# 1  Climate, Community, and Biodiversity Standards                514
# 2  Climate, Community, and Biodiversity Standards                562
# 3  Climate, Community, and Biodiversity Standards                576
# 4  Climate, Community, and Biodiversity Standards                594
#
#                                         resourceName  \
# 0  Reforestation of degraded grasslands in Uchind...
# 1  Promoting Sustainable Development through Natu...
# 2  The Kasigau Corridor REDD Project – Phase I Ru...
# 3  Restoration of degraded areas and reforestatio...
# 4                     TIST Program in Kenya, VCS 001
#
#                       proponent operator designee  \
# 0               GREEN RESOURCES     None     None
# 1    PICA DE HULE NATURAL, S.A.     None     None
# 2     Wildlife Works Carbon LLC     None     None
# 3                  Asorpar Ltd.     None     None
# 4  Clean Air Action Corporation     None     None
#
#                                   protocolCategories         resourceStatus  \
# 0      Afforestation, Reforestation and Revegetation  Verification approved
# 1      Afforestation, Reforestation and Revegetation  Verification approved
# 2  Reduced Emissions from Deforestation and Degra...  Verification approved
# 3      Afforestation, Reforestation and Revegetation  Verification approved
# 4      Afforestation, Reforestation and Revegetation  Verification approved
#
#      country  estAnnualEmissionReductions         region             version  \
# 0   Tanzania                      25000.0         Africa  CCB Second Edition
# 1  Guatemala                      46434.0  Latin America  CCB Second Edition
# 2      Kenya                     251432.0         Africa  CCB Second Edition
# 3   Colombia                      80000.0  Latin America  CCB Second Edition
# 4      Kenya                      14701.0         Africa  CCB Second Edition
#
#                           protocols
# 0                              None
# 1                 Biodiversity Gold
# 2   Climate Gold, Biodiversity Gold
# 3                              None
# 4                    Community Gold
